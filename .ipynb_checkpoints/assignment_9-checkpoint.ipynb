# %%
import sklearn
import pandas as pd
import json

# %%
# ------------------------------------------------------------------
# Read the settings json
# ------------------------------------------------------------------
with open('mushroom_features.json','r') as f:
    colmap = json.load(f)

# %%
# ------------------------------------------------------------------
# Label the data
# This is pulled from the data description
# ------------------------------------------------------------------
df = pd.read_csv('agaricus-lepiota.data')
columns = ['edibility','cap-shape','cap-surface','cap-color','bruises?','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat']
df.columns = columns
keepcolumns = [list(i.keys())[0] for i in colmap]
df = df[keepcolumns].copy()

# %%
# ------------------------------------------------------------------
# Split into poisonous/non-poisonous
# ------------------------------------------------------------------
tmpmask = df['edibility'] == 'e'
nonpsn  = df.loc[tmpmask].copy()
psn     = df.loc[~tmpmask].copy()
testdf  = df[set(keepcolumns)-set(['edibility'])]

# %%
# ------------------------------------------------------------------
# Apply the weights to the 
# ------------------------------------------------------------------
testdf['score'] = 0
for idx in testdf.index:
    # ------------------------------------------------------------------
    # Going through the features from the json
    # ------------------------------------------------------------------
    for fdict in colmap:
        col = list(fdict.keys())[0]
        # ------------------------------------------------------------------
        # If the column has been removed, skip
        # ------------------------------------------------------------------
        if col not in testdf:
            continue
        val  = testdf.loc[idx,col]
        # ------------------------------------------------------------------
        # There are some values that aren't represented in the description
        # ------------------------------------------------------------------
        if val not in fdict[col]:
            print(f'val not found:{val}')
            continue
        # ------------------------------------------------------------------
        # Increment
        # ------------------------------------------------------------------
        testdf.loc[idx,'score'] += fdict[col]['weight'] * fdict[col][val]
testdf
# Out:
#      stalk-surface-above-ring odor gill-color veil-type veil-color  \
# 0                           s    a          k         p          w
# 1                           s    l          n         p          w
# 2                           s    p          n         p          w
# 3                           s    n          k         p          w
# 4                           s    a          n         p          w
# ...                       ...  ...        ...       ...        ...
# 8118                        s    n          y         p          o
# 8119                        s    n          y         p          n
# 8120                        s    n          n         p          o
# 8121                        s    y          b         p          w
# 8122                        s    n          y         p          o
#
#      spore-print-color stalk-shape stalk-color-above-ring  \
# 0                    n           e                      w
# 1                    n           e                      w
# 2                    k           e                      w
# 3                    n           t                      w
# 4                    k           e                      w
# ...                ...         ...                    ...
# 8118                 b           e                      o
# 8119                 b           e                      o
# 8120                 b           e                      o
# 8121                 w           t                      w
# 8122                 o           e                      o
#
#      stalk-color-below-ring bruises? cap-color cap-surface habitat  \
# 0                         w        t         y           s       g
# 1                         w        t         w           s       m
# 2                         w        t         w           y       u
# 3                         w        f         g           s       g
# 4                         w        t         y           y       g
# ...                     ...      ...       ...         ...     ...
# 8118                      o        f         n           s       l
# 8119                      o        f         n           s       l
# 8120                      o        f         n           s       l
# 8121                      w        f         n           y       l
# 8122                      o        f         n           s       l
#
#      stalk-surface-below-ring  score
# 0                           s     66
# 1                           s     70
# 2                           s     67
# 3                           s     67
# 4                           s     64
# ...                       ...    ...
# 8118                        s     64
# 8119                        s     63
# 8120                        s     64
# 8121                        k     55
# 8122                        s     63
#
# [8123 rows x 15 columns]

# %%
# ------------------------------------------------------------------
# Cut off the sets
# ------------------------------------------------------------------
cutoff = testdf['score'].quantile(.75)
tmpmask = testdf['score'] >= cutoff
top_25 = testdf.loc[tmpmask].copy()
top_25
# Out:
#      stalk-surface-above-ring odor gill-color veil-type veil-color  \
# 0                           s    a          k         p          w
# 1                           s    l          n         p          w
# 2                           s    p          n         p          w
# 3                           s    n          k         p          w
# 5                           s    a          g         p          w
# ...                       ...  ...        ...       ...        ...
# 8093                        k    n          g         p          w
# 8095                        k    n          w         p          w
# 8098                        k    n          w         p          w
# 8108                        s    n          w         p          w
# 8110                        s    n          p         p          w
#
#      spore-print-color stalk-shape stalk-color-above-ring  \
# 0                    n           e                      w
# 1                    n           e                      w
# 2                    k           e                      w
# 3                    n           t                      w
# 5                    k           e                      w
# ...                ...         ...                    ...
# 8093                 w           e                      w
# 8095                 w           e                      w
# 8098                 w           e                      w
# 8108                 w           e                      w
# 8110                 w           e                      w
#
#      stalk-color-below-ring bruises? cap-color cap-surface habitat  \
# 0                         w        t         y           s       g
# 1                         w        t         w           s       m
# 2                         w        t         w           y       u
# 3                         w        f         g           s       g
# 5                         w        t         w           s       m
# ...                     ...      ...       ...         ...     ...
# 8093                      w        f         g           s       g
# 8095                      w        f         w           f       g
# 8098                      w        f         w           f       g
# 8108                      w        f         w           s       g
# 8110                      w        f         w           s       g
#
#      stalk-surface-below-ring  score
# 0                           s     66
# 1                           s     70
# 2                           s     67
# 3                           s     67
# 5                           s     70
# ...                       ...    ...
# 8093                        s     73
# 8095                        s     72
# 8098                        k     71
# 8108                        s     76
# 8110                        s     73
#
# [2057 rows x 15 columns]

# %%
# ------------------------------------------------------------------
# Cut off the sets
# ------------------------------------------------------------------
testdf['stewability'] = 0
testdf.loc[tmpmask,'stewability'] = 1
# Out:
#      stalk-surface-above-ring odor gill-color veil-type veil-color  \
# 0                           s    a          k         p          w
# 1                           s    l          n         p          w
# 2                           s    p          n         p          w
# 3                           s    n          k         p          w
# 4                           s    a          n         p          w
# ...                       ...  ...        ...       ...        ...
# 8118                        s    n          y         p          o
# 8119                        s    n          y         p          n
# 8120                        s    n          n         p          o
# 8121                        s    y          b         p          w
# 8122                        s    n          y         p          o
#
#      spore-print-color stalk-shape stalk-color-above-ring  \
# 0                    n           e                      w
# 1                    n           e                      w
# 2                    k           e                      w
# 3                    n           t                      w
# 4                    k           e                      w
# ...                ...         ...                    ...
# 8118                 b           e                      o
# 8119                 b           e                      o
# 8120                 b           e                      o
# 8121                 w           t                      w
# 8122                 o           e                      o
#
#      stalk-color-below-ring bruises? cap-color cap-surface habitat  \
# 0                         w        t         y           s       g
# 1                         w        t         w           s       m
# 2                         w        t         w           y       u
# 3                         w        f         g           s       g
# 4                         w        t         y           y       g
# ...                     ...      ...       ...         ...     ...
# 8118                      o        f         n           s       l
# 8119                      o        f         n           s       l
# 8120                      o        f         n           s       l
# 8121                      w        f         n           y       l
# 8122                      o        f         n           s       l
#
#      stalk-surface-below-ring  score  stewability
# 0                           s     66            1
# 1                           s     70            1
# 2                           s     67            1
# 3                           s     67            1
# 4                           s     64            0
# ...                       ...    ...          ...
# 8118                        s     64            0
# 8119                        s     63            0
# 8120                        s     64            0
# 8121                        k     55            0
# 8122                        s     63            0
#
# [8123 rows x 16 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
# ------------------------------------------------------------------
# Encode the columns
# ------------------------------------------------------------------
x = testdf.drop(['score','stewability'],axis=1)
xcols = x.columns.to_list()
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(x)
x = enc.transform(x).toarray()
# Out:
# array([[0., 0., 1., ..., 0., 1., 0.],
#        [0., 0., 1., ..., 0., 1., 0.],
#        [0., 0., 1., ..., 0., 1., 0.],
#        ...,
#        [0., 0., 1., ..., 0., 1., 0.],
#        [0., 0., 1., ..., 1., 0., 0.],
#        [0., 0., 1., ..., 0., 1., 0.]])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# ------------------------------------------------------------------
# Split the data set
# ------------------------------------------------------------------
y = testdf['stewability'].to_numpy()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# ------------------------------------------------------------------
# Create the model
# ------------------------------------------------------------------
model = RandomForestClassifier(random_state=1)
model.fit(x_train,y_train)
# ------------------------------------------------------------------
# Run the model
# ------------------------------------------------------------------
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# ------------------------------------------------------------------
# Confusion matrix
# ------------------------------------------------------------------
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", xticklabels=['neg', 'pos'], yticklabels=['neg', 'pos'])
# Out:
# <AxesSubplot:>

# %%
finaldf = df.copy()
# ------------------------------------------------------------------
# Run for edible and non-edible
# ------------------------------------------------------------------
finaldf['prediction'] = model.predict(x)
tmpmask = finaldf['edibility'] == 'e'
widowersdf    = finaldf.loc[~tmpmask]
deliciousstew = finaldf.loc[tmpmask]

# %%
# ------------------------------------------------------------------
# Histograms of columns
# ------------------------------------------------------------------

# %%
# ------------------------------------------------------------------
# Random Forest reports (visualization and feature importance)
# ------------------------------------------------------------------

# %%
# ------------------------------------------------------------------
# Write-up (model is the product/exhibition of some "random" mushrooms)
# ------------------------------------------------------------------
